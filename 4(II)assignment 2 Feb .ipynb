# %%
1).  For Loop:   A for loop is an iteration method that is best used when you know the number of iterations ahead of time.
                 It’s always followed by the initialization, expression and increment statements.
                 example 
                 for i in range(10):
                       print(i)
                    
     While Loop: A while loop is an iteration method that is best used when you don't know the number of iterations ahead
                 of time. The contents of the loop are executed as long as the expression evaluates to true.
                 example:
                 n = int(input("Enter your limit"))
                 starting_point = 0
                 counter = 1 
                 while counter<=n:
                 starting_point = starting_point + counter 
                 counter = counter +1

2) 
#sum of first 10 natural number using "for loop"
sum = 0
for i in range(10):
    sum = sum + i+1
else:
    print(sum)
#product of first 10 natural number using  "for loop"
product = 1
for i in range(10):
    product= product*(i+1)
else:
    print(product) 
#sum of first 10 natural number using "while loop"
sum = 0
i = 1 
while i <=10:
    sum = sum + i
    i = i +1
else:
    print(sum)
#product of first 10 natural number using "while loop
product = 1
i = 1
while i<=10:
    product= product*i
    i = i +1
else:
    print(product)
            
3)   #To find electricity bill
                                                                                                                                
u = int(input("Enter the units of electricity consumed in a month by you"))
if u <0:
    print("please enter the valid units")
else:
    if u <= 100:
        print("your electricity bill is :" , u*(4.5))
    elif u >100 and u <=200:
        print("your electricity bill is :" , 100*(4.5) + (u-100)*6)
    elif u >200 and u <=300:
        print("your electricity bill is :" , 100*(4.5) + 100*6 + (u-200)*10)
    elif u>300:
        print("your electricity bill is :" , 100*(4.5) + 100*6 + 100*10 + (u-300)*20)   
                                                                                                                           
4) 
#with help of for loop
a = range(1,101)
l = list(a)           #l will be list of 1 to 100 numbers
l1 = []               #l1 will be list of cube of 1 to 100 numbers
l2 = []               #l2 will be list of those number from 1 to 100 whose cube is divisible by 4 or 5 
for i in l:
    i= i**3
    l1.append(i)
    
for j in l:
    if (j**3)%4==0 or (j**3)%5==0:
        l2.append(j)
l,l1,l2

#with help of while loop
a = range(1,101)
l = list(a)          
i = 1
j= 1
l1 = []              
l2 = []             
while i <=100:
    l1.append(i**3)
    i=i+1

while j <=100:
    if (j**3)%4==0 or (j**3)%5==0:
        l2.append(j)
    j = j+1

l,l1,l2


5)
string = "I want to become a data scientist"
l = []
for i in range(len(string)):
    if string[i] == "a" or string[i] == "e" or string[i] == "i" or string[i] == "o" or string[i] == "u" or string[i] == "A" or string[i] == "E"  or string[i] == "I" or string[i] == "O" or string[i] == "U":
        l.append(string[i]) 
len(l

# %%
sum = 0
for i in range(10):
    sum = sum + i+1
else:
    print(sum)
# Out:
# 55
